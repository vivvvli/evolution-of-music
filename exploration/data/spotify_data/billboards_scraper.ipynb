# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup, Comment
import pandas as pd
import requests
import numpy as np
import os
from collections import OrderedDict
import main
sp = main.sp

# %% [markdown]
# Code Source: https://github.com/RosebudAnwuri/TheArtandScienceofData/blob/master/The%20Making%20of%20Great%20Music/scripts/music_sentiment.py
#
# Endpoint Returned:
# https://developer.spotify.com/documentation/web-api/reference/#endpoint-get-audio-features

# %%
def get_spotify_features(track, artist):
    artist = artist.split(' ', 1)[0]
    #Search for Spofity song ID 
    songs=sp.search(q='track:'+track+' '+'artist:'+artist+'*' , type='track')
    items = songs['tracks']['items']
    if len(items) ==0:
        return([0]*len(features))
    else:
        track = items[0]
        song_id = str(track["id"])
        #Use ID to get Song features
        track_features=sp.audio_features(song_id)
        if len(track_features[0]) <18:
            return([0]*len(features))
        else:
            features_to_df = np.array(track_features)[0]
            #Order Dictionary
            features_to_df = OrderedDict(features_to_df)
            #Get Dictionary values
            feature_values = features_to_df.values()
            return(feature_values)

# %%
list(get_spotify_features('peaches','justin'))[0]
# Out:
# 0.677

# %% [markdown]
# Function for getting charts for first of every month since the year 2000.

# %%
def append_song_stats(year):
    song_list = []
    for each in range(0,100):
        song = []
        rank = list(song_soup)[2].findAll("span",{'class': 'chart-element__rank__number'})[each].text
        artist = list(song_soup)[2].findAll("span",{'class': 'chart-element__information__artist text--truncate color--secondary'})[each].text
        song_name = list(song_soup)[2].findAll("span",{'class': 'chart-element__information__song text--truncate color--primary'})[each].text
        peak = list(song_soup)[2].findAll("span",{'class': 'chart-element__meta text--center color--secondary text--peak'})[each].text
        woc = list(song_soup)[2].findAll("span",{'class': 'chart-element__meta text--center color--secondary text--week'})[each].text
        # some songs are listed differently in Billboards vs Spotify; it's hard to account for those so we need to use a try/except 
        song.append(year + '-01')
        song.append(rank)
        song.append(artist)
        song.append(song_name)
        song.append(peak)
        song.append(woc)
        try:
            song_features = list(get_spotify_features(song_name,artist))
            for each in song_features:
                song.append(each)
        except: 
            song_features = 'N/A'
            for each in (0,18):
                song.append(song_features)
        song_list.append(song)
    return song_list

# %%
# Initialize .csv writer
writer = pd.ExcelWriter('billboard_charts.xlsx', engine='xlsxwriter')

# Push data to .csv file (1 sheet per year)
# Only using data as far back as 2000
for year in range(2000,2020):
    for month in range(1,13):
        year_month = str(year) + '-' + str(month).zfill(2)
        url = "https://www.billboard.com/charts/hot-100/{}-01".format(year_month)
        page = requests.get(url)
        song_soup = BeautifulSoup(page.content, 'html.parser')

        headers = ['year','rank',
                       'artist',
                       'song_name',
                        'peak',
                        'woc',
                   'danceability',
                       'energy', 
                       'key', 
                   'loudness',
                   'mode',
                   'speechiness',
                   'acousticness',
                   'instrumentalnes',
                   'liveness',
                   'valence',
                   'tempo',
                   'type',
                   'id',
                   'uri',
                   'track_href',
                   'analysis_url',
                   'duration_ms',
                   'time_signature'
                      ]

        song_list = append_song_stats(year_month)
        print(year_month + '-01' + ' successfully processed')
        stats = pd.DataFrame(song_list, columns = headers)
        stats.to_excel(writer, sheet_name='chart_data_{}-01'.format(year_month), index = False)
    
# Save .csv data
print('Scraping Completed!')
writer.save()
# Out:
# 2000-01-01 successfully processed
# 2000-02-01 successfully processed
# 2000-03-01 successfully processed
# 2000-04-01 successfully processed
# 2000-05-01 successfully processed
# 2000-06-01 successfully processed
# 2000-07-01 successfully processed
# 2000-08-01 successfully processed
# 2000-09-01 successfully processed
# 2000-10-01 successfully processed
# 2000-11-01 successfully processed
# 2000-12-01 successfully processed
# 2001-01-01 successfully processed
# 2001-02-01 successfully processed
# 2001-03-01 successfully processed
# 2001-04-01 successfully processed
# 2001-05-01 successfully processed
# 2001-06-01 successfully processed
# 2001-07-01 successfully processed
# 2001-08-01 successfully processed
# 2001-09-01 successfully processed
# 2001-10-01 successfully processed
# 2001-11-01 successfully processed
# 2001-12-01 successfully processed
# 2002-01-01 successfully processed
# 2002-02-01 successfully processed
# 2002-03-01 successfully processed
# 2002-04-01 successfully processed
# 2002-05-01 successfully processed
# 2002-06-01 successfully processed
# 2002-07-01 successfully processed
# 2002-08-01 successfully processed
# 2002-09-01 successfully processed
# 2002-10-01 successfully processed
# 2002-11-01 successfully processed
# 2002-12-01 successfully processed
# 2003-01-01 successfully processed
# 2003-02-01 successfully processed
# 2003-03-01 successfully processed
# 2003-04-01 successfully processed
# 2003-05-01 successfully processed
# 2003-06-01 successfully processed
# 2003-07-01 successfully processed
# 2003-08-01 successfully processed
# 2003-09-01 successfully processed
# 2003-10-01 successfully processed
# 2003-11-01 successfully processed
# 2003-12-01 successfully processed
# 2004-01-01 successfully processed
# 2004-02-01 successfully processed
# 2004-03-01 successfully processed
# 2004-04-01 successfully processed
# 2004-05-01 successfully processed
# 2004-06-01 successfully processed
# 2004-07-01 successfully processed
# 2004-08-01 successfully processed
# 2004-09-01 successfully processed
# 2004-10-01 successfully processed
# 2004-11-01 successfully processed
# 2004-12-01 successfully processed
# 2005-01-01 successfully processed
# 2005-02-01 successfully processed
# 2005-03-01 successfully processed
# 2005-04-01 successfully processed
# 2005-05-01 successfully processed
# 2005-06-01 successfully processed
# 2005-07-01 successfully processed
# 2005-08-01 successfully processed
# 2005-09-01 successfully processed
# 2005-10-01 successfully processed
# 2005-11-01 successfully processed
# 2005-12-01 successfully processed
# 2006-01-01 successfully processed
# 2006-02-01 successfully processed
# 2006-03-01 successfully processed
# 2006-04-01 successfully processed
# 2006-05-01 successfully processed
# 2006-06-01 successfully processed
# 2006-07-01 successfully processed
# 2006-08-01 successfully processed
# 2006-09-01 successfully processed
# 2006-10-01 successfully processed
# 2006-11-01 successfully processed
# 2006-12-01 successfully processed
# 2007-01-01 successfully processed
# 2007-02-01 successfully processed
# 2007-03-01 successfully processed
# 2007-04-01 successfully processed
# 2007-05-01 successfully processed
# 2007-06-01 successfully processed
# 2007-07-01 successfully processed
# 2007-08-01 successfully processed
# 2007-09-01 successfully processed
# 2007-10-01 successfully processed
# 2007-11-01 successfully processed
# 2007-12-01 successfully processed
# 2008-01-01 successfully processed
# 2008-02-01 successfully processed
# 2008-03-01 successfully processed
# 2008-04-01 successfully processed
# 2008-05-01 successfully processed
# 2008-06-01 successfully processed
# 2008-07-01 successfully processed
# 2008-08-01 successfully processed
# 2008-09-01 successfully processed
# 2008-10-01 successfully processed
# 2008-11-01 successfully processed
# 2008-12-01 successfully processed
# 2009-01-01 successfully processed
# 2009-02-01 successfully processed
# 2009-03-01 successfully processed
# 2009-04-01 successfully processed
# 2009-05-01 successfully processed
# 2009-06-01 successfully processed
# 2009-07-01 successfully processed
# 2009-08-01 successfully processed
# 2009-09-01 successfully processed
# 2009-10-01 successfully processed
# 2009-11-01 successfully processed
# 2009-12-01 successfully processed
# 2010-01-01 successfully processed
# 2010-02-01 successfully processed
# 2010-03-01 successfully processed
# 2010-04-01 successfully processed
# 2010-05-01 successfully processed
# 2010-06-01 successfully processed
# 2010-07-01 successfully processed
# 2010-08-01 successfully processed
# 2010-09-01 successfully processed
# 2010-10-01 successfully processed
# 2010-11-01 successfully processed
# 2010-12-01 successfully processed
# 2011-01-01 successfully processed
# 2011-02-01 successfully processed
# 2011-03-01 successfully processed
# 2011-04-01 successfully processed
# 2011-05-01 successfully processed
# 2011-06-01 successfully processed
# 2011-07-01 successfully processed
# 2011-08-01 successfully processed
# 2011-09-01 successfully processed
# 2011-10-01 successfully processed
# 2011-11-01 successfully processed
# 2011-12-01 successfully processed
# 2012-01-01 successfully processed
# 2012-02-01 successfully processed
# 2012-03-01 successfully processed
# 2012-04-01 successfully processed
# 2012-05-01 successfully processed
# 2012-06-01 successfully processed
# 2012-07-01 successfully processed
# 2012-08-01 successfully processed
# 2012-09-01 successfully processed
# 2012-10-01 successfully processed
# 2012-11-01 successfully processed
# 2012-12-01 successfully processed
# 2013-01-01 successfully processed
# 2013-02-01 successfully processed
# 2013-03-01 successfully processed
# 2013-04-01 successfully processed
# 2013-05-01 successfully processed
# 2013-06-01 successfully processed
# 2013-07-01 successfully processed
# 2013-08-01 successfully processed
# 2013-09-01 successfully processed
# 2013-10-01 successfully processed
# 2013-11-01 successfully processed
# 2013-12-01 successfully processed
# 2014-01-01 successfully processed
# 2014-02-01 successfully processed
# 2014-03-01 successfully processed
# 2014-04-01 successfully processed
# 2014-05-01 successfully processed
# 2014-06-01 successfully processed
# 2014-07-01 successfully processed
# 2014-08-01 successfully processed
# 2014-09-01 successfully processed
# 2014-10-01 successfully processed
# 2014-11-01 successfully processed
# 2014-12-01 successfully processed
# 2015-01-01 successfully processed
# 2015-02-01 successfully processed
# 2015-03-01 successfully processed
# 2015-04-01 successfully processed
# 2015-05-01 successfully processed
# 2015-06-01 successfully processed
# 2015-07-01 successfully processed
# 2015-08-01 successfully processed
# 2015-09-01 successfully processed
# 2015-10-01 successfully processed
# 2015-11-01 successfully processed
# 2015-12-01 successfully processed
# 2016-01-01 successfully processed
# 2016-02-01 successfully processed
# 2016-03-01 successfully processed
# 2016-04-01 successfully processed
# 2016-05-01 successfully processed
# 2016-06-01 successfully processed
# 2016-07-01 successfully processed
# 2016-08-01 successfully processed
# 2016-09-01 successfully processed
# 2016-10-01 successfully processed
# 2016-11-01 successfully processed
# 2016-12-01 successfully processed
# 2017-01-01 successfully processed
# 2017-02-01 successfully processed
# 2017-03-01 successfully processed
# 2017-04-01 successfully processed
# 2017-05-01 successfully processed
# 2017-06-01 successfully processed
# 2017-07-01 successfully processed
# 2017-08-01 successfully processed
# 2017-09-01 successfully processed
# 2017-10-01 successfully processed
# 2017-11-01 successfully processed
# 2017-12-01 successfully processed
# 2018-01-01 successfully processed
# 2018-02-01 successfully processed
# 2018-03-01 successfully processed
# 2018-04-01 successfully processed
# 2018-05-01 successfully processed
# 2018-06-01 successfully processed
# 2018-07-01 successfully processed
# 2018-08-01 successfully processed
# 2018-09-01 successfully processed
# 2018-10-01 successfully processed
# 2018-11-01 successfully processed
# 2018-12-01 successfully processed
# 2019-01-01 successfully processed
# 2019-02-01 successfully processed
# 2019-03-01 successfully processed
# 2019-04-01 successfully processed
# 2019-05-01 successfully processed
# 2019-06-01 successfully processed
# 2019-07-01 successfully processed
# 2019-08-01 successfully processed
# 2019-09-01 successfully processed
# 2019-10-01 successfully processed
# 2019-11-01 successfully processed
# 2019-12-01 successfully processed
# Scraping Completed!
