# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

xls = pd.ExcelFile('spotify_charts_features.xlsx')

map = {}
for sheet_name in xls.sheet_names:
    map[sheet_name] = xls.parse(sheet_name)

# %%
# putting all the years together
temp = pd.DataFrame()
for key, value in map.items():
    temp1 = pd.DataFrame()
    temp1 = temp1.append(value)
    temp1['date'] = pd.to_datetime(key[-7:])
    temp = temp.append(temp1)

# compute the correlation matrix
corr = temp.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# will needt o do a line graph of each feature to see over time how things have changed

# %%
temp
# Out:
#     rank                    artist                                song_name  \
# 0      1     The Weeknd, Daft Punk                                  Starboy
# 1      2  The Chainsmokers, Halsey                                   Closer
# 2      3   DJ Snake, Justin Bieber                          Let Me Love You
# 3      4              Clean Bandit  Rockabye (feat. Sean Paul & Anne-Marie)
# 4      5       Drake, WizKid, Kyla                                One Dance
# ..   ...                       ...                                      ...
# 95   196                     Queen      Bohemian Rhapsody - Remastered 2011
# 96   197                The Weeknd                             In Your Eyes
# 97   198                   BANNERS                           Someone To You
# 98   199                    Polo G                            Martin & Gina
# 99   200                Marshmello                    Be Kind (with Halsey)
#
# ...

# %%
plt.figure(figsize=(15, 3))
plt.plot(temp[temp['rank']==1].date, temp[temp['rank']==1].duration_ms)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-583c981e54d8> in <module>
#       1 plt.figure(figsize=(15, 3))
# ----> 2 plt.plot(temp[temp['date']=='2017-01-01'].rank, temp[temp['date']=='2017-01-01'].duration_ms)
#       3 plt.show()
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
test = temp[temp['Percentage'] > 80]
